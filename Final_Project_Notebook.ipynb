# %% [markdown]
# # Final Project Notebook
#
# Use the follow cells prompts to complete the final project for the course. Everything you need should be present in this notebook or previous notebooks we've used in class. You can work together as needed.
#
#  - You will need to name your own dataset and use that name throughout
#  - There are sections where you need to make changes the code and insert new code this will be noted in the code provided
#  - You may get frustrated along the way, this is totally normal, just remember even small changes to the code make a huge difference.

# %% [markdown]
# ## Question Fork the Repository
# i. Include a screenshot of the forked repo in your GitHub account
#
# To fork the repository:
# 1. Go to https://github.com/NovaVolunteer/ds1001_final
# 2. Click the "Fork" button in the top right corner
# 3. The repo will be forked to your GitHub account
# 4. Take a screenshot of your forked repository

# %% [markdown]
# ### You should now be able to open your cloned repo in google collab, use the code below.
#
# ### It's very helpful to have the variable inspector open while you go through this process. To do so go to tools>command palette>show variable inspector
#
# ### It's also helpful to open up the folder tree on the left menu bar. Just click on the folder icon and then the ds1001_final folder. The data is located in the data folder in the processed sub-folder.

# %%
# !git clone "https://github.com/username/repository.git"
# This script clones a GitHub repository using Git command line tool. 
# Insert the path to your desired repository in place of the URL.
# Out:
# Cloning into 'repository'...
# remote: Repository not found.
# fatal: repository 'https://github.com/username/repository.git/' not found

# %% [markdown]
# ## Systems

# %%
# Activate the finalproj environment
# !source ds1001_final/ds1001_final/finalproj/bin/activate
# Out:
# /bin/bash: line 1: ds1001_final/ds1001_final/finalproj/bin/activate: No such file or directory

# %%
### You can use this command to list all the packages in your environment
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# attrs                   26.1.0
# Automat                 25.4.16
# certifi                 2026.4.22
# cffi                    2.0.0
# charset-normalizer      3.4.7
# comm                    0.2.3
# constantly              23.10.4
# contourpy               1.3.3
# cryptography            47.0.0
# cssselect               1.4.0
# cycler                  0.12.1
# debugpy                 1.8.20
# decorator               5.2.1
# defusedxml              0.7.1
# executing               2.2.1
# fairlearn               0.13.0
# filelock                3.29.0
# fonttools               4.62.1
# greenlet                3.4.0
# happybase               1.3.0
# hyperlink               21.0.0
# idna                    3.13
# importlib_resources     7.1.0
# Incremental             24.11.0
# ipykernel               7.2.0
# ipython                 9.13.0
# ipython_pygments_lexers 1.1.1
# itemadapter             0.13.1
# itemloaders             1.4.0
# jedi                    0.19.2
# jmespath                1.1.0
# joblib                  1.5.3
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# kiwisolver              1.5.0
# logzero                 1.7.0
# lxml                    6.1.0
# matplotlib              3.10.9
# matplotlib-inline       0.2.1
# narwhals                2.20.0
# nest-asyncio            1.6.0
# numpy                   2.4.4
# packaging               26.2
# pandas                  3.0.2
# parsel                  1.11.0
# parso                   0.8.6
# pexpect                 4.9.0
# pillow                  12.2.0
# pip                     26.0.1
# platformdirs            4.9.6
# ply                     3.11
# prompt_toolkit          3.0.52
# Protego                 0.6.0
# psutil                  7.2.2
# ptyprocess              0.7.0
# pure_eval               0.2.3
# pyasn1                  0.6.3
# pyasn1_modules          0.4.2
# pycparser               3.0
# PyDispatcher            2.0.7
# Pygments                2.20.0
# PyMySQL                 1.1.2
# pyOpenSSL               26.1.0
# pyparsing               3.3.2
# pyquery                 2.0.1
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# queuelib                1.9.0
# redis                   7.4.0
# requests                2.33.1
# requests-file           3.0.1
# scikit-learn            1.8.0
# scipy                   1.15.3
# Scrapy                  2.15.1
# scrapy-redis            0.9.1
# scrapyd                 1.6.0
# scrapyd-client          2.0.3
# seaborn                 0.13.2
# service-identity        24.2.0
# setuptools              80.10.2
# six                     1.17.0
# SQLAlchemy              2.0.49
# stack-data              0.6.3
# threadpoolctl           3.6.0
# thriftpy2               0.6.0
# tld                     0.13.2
# tldextract              5.3.1
# tornado                 6.5.5
# traitlets               5.14.3
# Twisted                 25.5.0
# typing_extensions       4.15.0
# uberegg                 0.1.1
# urllib3                 2.6.3
# w3lib                   2.4.1
# wcwidth                 0.6.0
# XX                      3.3.2
# zope.interface          8.4

# %%
# !pip install "XX"

#You'll likely need to install the fairlearn packages, if not already installed.
#Are there additional packages to install? (Cross check with the list above to 
# ensure all packages are installed)
# Out:
# Requirement already satisfied: XX in ./PhoebePark_env/lib/python3.12/site-packages (3.3.2)
# Requirement already satisfied: scrapy in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (2.15.1)
# Requirement already satisfied: scrapyd in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (1.6.0)
# Requirement already satisfied: scrapyd-client in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (2.0.3)
# Requirement already satisfied: scrapy-redis in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (0.9.1)
# Requirement already satisfied: pyquery in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (2.0.1)
# Requirement already satisfied: redis in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (7.4.0)
# Requirement already satisfied: requests in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (2.33.1)
# Requirement already satisfied: pymysql in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (1.1.2)
# Requirement already satisfied: sqlalchemy in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (2.0.49)
# Requirement already satisfied: logzero in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (1.7.0)
# Requirement already satisfied: happybase in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (1.3.0)
# Requirement already satisfied: tld in ./PhoebePark_env/lib/python3.12/site-packages (from XX) (0.13.2)
# Requirement already satisfied: six in ./PhoebePark_env/lib/python3.12/site-packages (from happybase->XX) (1.17.0)
# Requirement already satisfied: thriftpy2>=0.4 in ./PhoebePark_env/lib/python3.12/site-packages (from happybase->XX) (0.6.0)
# Requirement already satisfied: importlib-resources in ./PhoebePark_env/lib/python3.12/site-packages (from happybase->XX) (7.1.0)
# Requirement already satisfied: ply<4.0,>=3.4 in ./PhoebePark_env/lib/python3.12/site-packages (from thriftpy2>=0.4->happybase->XX) (3.11)
# Requirement already satisfied: lxml>=2.1 in ./PhoebePark_env/lib/python3.12/site-packages (from pyquery->XX) (6.1.0)
# Requirement already satisfied: cssselect>=1.2.0 in ./PhoebePark_env/lib/python3.12/site-packages (from pyquery->XX) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./PhoebePark_env/lib/python3.12/site-packages (from requests->XX) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./PhoebePark_env/lib/python3.12/site-packages (from requests->XX) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in ./PhoebePark_env/lib/python3.12/site-packages (from requests->XX) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./PhoebePark_env/lib/python3.12/site-packages (from requests->XX) (2026.4.22)
# Requirement already satisfied: cryptography>=37.0.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (47.0.0)
# Requirement already satisfied: defusedxml>=0.7.1 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (0.13.1)
# Requirement already satisfied: itemloaders>=1.0.1 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (1.4.0)
# Requirement already satisfied: packaging in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (26.2)
# Requirement already satisfied: parsel>=1.5.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (1.11.0)
# Requirement already satisfied: protego>=0.1.15 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (0.6.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (2.0.7)
# Requirement already satisfied: pyopenssl>=22.0.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (26.1.0)
# Requirement already satisfied: queuelib>=1.4.2 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (1.9.0)
# Requirement already satisfied: service-identity>=18.1.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (24.2.0)
# Requirement already satisfied: tldextract in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (5.3.1)
# Requirement already satisfied: twisted<=25.5.0,>=21.7.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (25.5.0)
# Requirement already satisfied: w3lib>=1.17.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (2.4.1)
# Requirement already satisfied: zope-interface>=5.1.0 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapy->XX) (8.4)
# Requirement already satisfied: attrs>=22.2.0 in ./PhoebePark_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (26.1.0)
# Requirement already satisfied: automat>=24.8.0 in ./PhoebePark_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in ./PhoebePark_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in ./PhoebePark_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in ./PhoebePark_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (24.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./PhoebePark_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in ./PhoebePark_env/lib/python3.12/site-packages (from cryptography>=37.0.0->scrapy->XX) (2.0.0)
# Requirement already satisfied: pycparser in ./PhoebePark_env/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=37.0.0->scrapy->XX) (3.0)
# Requirement already satisfied: jmespath>=0.9.5 in ./PhoebePark_env/lib/python3.12/site-packages (from itemloaders>=1.0.1->scrapy->XX) (1.1.0)
# Requirement already satisfied: pyasn1 in ./PhoebePark_env/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (0.6.3)
# Requirement already satisfied: pyasn1-modules in ./PhoebePark_env/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (0.4.2)
# Requirement already satisfied: setuptools<81 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapyd->XX) (80.10.2)
# Requirement already satisfied: pip in ./PhoebePark_env/lib/python3.12/site-packages (from scrapyd-client->XX) (26.0.1)
# Requirement already satisfied: uberegg>=0.1.1 in ./PhoebePark_env/lib/python3.12/site-packages (from scrapyd-client->XX) (0.1.1)
# Requirement already satisfied: greenlet>=1 in ./PhoebePark_env/lib/python3.12/site-packages (from sqlalchemy->XX) (3.4.0)
# Requirement already satisfied: requests-file>=1.4 in ./PhoebePark_env/lib/python3.12/site-packages (from tldextract->scrapy->XX) (3.0.1)
# Requirement already satisfied: filelock>=3.0.8 in ./PhoebePark_env/lib/python3.12/site-packages (from tldextract->scrapy->XX) (3.29.0)

# %% [markdown]
# ### Check !pip list again to confirm installations

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import fairlearn.metrics
from fairlearn.metrics import MetricFrame
from fairlearn.metrics import count, true_positive_rate, false_positive_rate, selection_rate, demographic_parity_ratio

# %% [markdown]
# ## Design: Data prep and exploration

# %%
data = pd.read_csv('ds1001_final/data/processed/bank_final.csv') # the data is the data folder, 
#you'll need to use the correct path to the dataset. 

# How many rows are in the dataframe? How many columns?

# %%
# Explore the variables a bit more, create histograms for the numerics values and bar charts for the categorical.
# Histograms for numeric variables
numeric_columns = data.select_dtypes(include=['number']).columns
for col in numeric_columns: 
    plt.figure(figsize=(10, 6))
    sns.histplot(data[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
# Bar charts for categorical variables
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=data[col])
    plt.title(f'Bar Chart of {col}')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipykernel_2842/706812485.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = data.select_dtypes(include=['object', 'category']).columns

# %%
# How many numeric columns are in the data set?
num_numeric_columns = data.select_dtypes(include=['number']).shape[1]
num_numeric_columns
# Out:
# 5

# %%
# Normalization
scaler = MinMaxScaler()
data[data.select_dtypes(include=['number']).columns] = scaler.fit_transform(data.select_dtypes(include=['number']))

# %%
# Likely need to convert categorical columns to category dtype
for col in data.select_dtypes(include=['object']).columns:
    data[col] = data[col].astype('category')
# Out:
# /tmp/ipykernel_2842/177180598.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in data.select_dtypes(include=['object']).columns:

# %%
# Creating dummy variables, make sure the variables that need to be converted to dummies are categorical, not numeric.
# This might require you to convert some columns to categorical first using astype('category')
data = pd.get_dummies(data, drop_first=True)

# %%
# Display missing data using the isnull function, is there any missing data?
print(data.isnull().sum())
# Out:
# age                    0
# balance                0
# duration               0
# contactndays           0
# signed up              0
# job_blue-collar        0
# job_entrepreneur       0
# job_housemaid          0
# job_management         0
# job_retired            0
# job_self-employed      0
# job_services           0
# job_student            0
# job_technician         0
# job_unemployed         0
# job_unknown            0
# marital_married        0
# marital_single         0
# education_secondary    0
# education_tertiary     0
# education_unknown      0
# race_black             0
# race_hispanic          0
# race_white             0
# default_yes            0
# housing_yes            0
# contact_telephone      0
# contact_unknown        0
# gender_m               0
# dtype: int64

# %%
# remove missing values if needed
data = data.dropna()

# %%
# Scatterplot between two continuous variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data.age, y=data.duration, data=data)  # Replace 'Variable1' and 'Variable2' with your column names
plt.title('Scatterplot of age vs duration')
plt.savefig('scatterplot.png')  # Save the scatterplot image
plt.show()

# %%
# Density chart of a continuous variable
plt.figure(figsize=(10, 6))
sns.kdeplot(data['age'], fill=True)  # Replace 'ContinuousVariable' with your column name
plt.title('Density Chart of age')
plt.show()

# %%
#Correlation matrix, make sure to only include numeric variables
num_values = data.select_dtypes(include=['number'])
correlation_matrix = num_values.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Analytics: Build a model and Tune it for best Best Performance

# %%
# What is the ‘target’ of a model and what is the prevalence of the target in your dataset? Remember prevalence 
# is the proportion of records that take on the value of interest for the target variable, usually the positive class.
target_prevalence = data['signed up'].sum()  # Replace 'TargetVariable' with your target column name
print(f'Target Prevalence: {target_prevalence}')
# Out:
# Target Prevalence: 5074.0

# %%
# Divide the dataset into features and target
target = data['signed up']  # Replace 'TargetVariable' with your actual target column name and "xx" with your dataframe name
features = data.drop(columns=['signed up']) # Drop the target column from features

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Include your table for the 10 values of k you tried and the corresponding accuracies.

accuracy_results = {}

# Replace x with your desired range values, explain what is happening in this loop
for k in range(1, 11):  
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train, y_train)
    accuracy = knn_model.score(X_test, y_test)
    accuracy_results[k] = accuracy

# %%
#graph of accuracy vs k values
plt.figure(figsize=(10, 6))
plt.plot(list(accuracy_results.keys()), list(accuracy_results.values()), marker='o')
plt.title('KNN Accuracy vs K Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.xticks(list(accuracy_results.keys()))
plt.grid()
plt.show()
list(accuracy_results.values())
# Out:
# [0.8589273435709375,
#  0.8843685537474215,
#  0.8766903506761403,
#  0.880930552372221,
#  0.8795553518221407,
#  0.8826495530598212,
#  0.8802429520971808,
#  0.8821911528764611,
#  0.8827641531056613,
#  0.8831079532431813]

# %%
# using the hyperparameter k that gave the best accuracy, rerun the model and generate 
# predictions on the test set. Explain why you choose this k value.
best_k = 2  # Replace 'xx' with the best k value found
knn_model = KNeighborsClassifier(n_neighbors=best_k)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)

# %% [markdown]
# ## Value: Evaluation and Protected Classes

# %%
# create a confusion matrix for your model's predictions. 
# What does the confusion matrix tell you about your model's performance?
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %%
#We already have a model above using KNN so we can use the results to compute fairness metrics

# Compute fairness metrics using Fairlearn

my_metrics = {
    'true positive rate' : true_positive_rate,
    'false positive rate' : false_positive_rate,
    'selection rate' : selection_rate,
    'count' : count
}
# Construct a MetricFrame for race
mf_race = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test['race_hispanic']  # Replace with your first protected class
)

# Construct a MetricFrame for gender
mf_gender = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test['gender_m']  # Replace second protected class 
)

# %%
X_test.columns
# Out:
# Index(['age', 'balance', 'duration', 'contactndays', 'job_blue-collar',
#        'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired',
#        'job_self-employed', 'job_services', 'job_student', 'job_technician',
#        'job_unemployed', 'job_unknown', 'marital_married', 'marital_single',
#        'education_secondary', 'education_tertiary', 'education_unknown',
#        'race_black', 'race_hispanic', 'race_white', 'default_yes',
#        'housing_yes', 'contact_telephone', 'contact_unknown', 'gender_m'],
#       dtype='str')

# %%
mf_race.by_group #What do the results show? Change the mf_race with each subgroup and report the findings. This means
# you should run this cell multiple times, once for each of the levels in the race variable.
# Out:
#                true positive rate  false positive rate  selection rate   count
# race_hispanic
# False                    0.118863             0.012745        0.025228  6580.0
# True                     0.111538             0.011665        0.023765  2146.0

# %%
mf_gender.by_group #What do the results show? There's only two groups here so we don't need to change anything. 
# in the metric frame.
# Out:
#           true positive rate  false positive rate  selection rate   count
# gender_m
# False               0.117117             0.012645        0.025971  4351.0
# True                0.116910             0.012320        0.023771  4375.0

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# two fairness ratios using the gender_m feature, which is bi-variate. What do the results show, is the model more or 
# less fair with this grouping?

dpr_gender = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Demographic Parity ratio:\t", dpr_gender)

eodds_gender = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Equalized Odds ratio:\t\t", eodds_gender)
# Out:
# Demographic Parity ratio:	 0.915305183312263
# Equalized Odds ratio:		 0.9743326488706366

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# the same features above only using a filtered search to pull in all the possibilities of features
# starting with "race". What do the results show, is the model more or less fair with this grouping?

dpr_race = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Demographic Parity ratio:\t", dpr_race)

eodds_race = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Equalized Odds ratio:\t\t", eodds_race)
# Out:
# Demographic Parity ratio:	 0.7838274163512946
# Equalized Odds ratio:		 0.5863736263736264

# %%
#Optional code to add, commit, and push changes to your GitHub repository
# !git add .
# !git commit -m "Almost complete with value part" # This will commit your changes to git. 
# !git push # This will push your changes to back to your remote repository on GitHub.
# Out:
# [main 05854c7] Almost complete with value part
#  23090 files changed, 4944465 insertions(+)
#  create mode 100644 Final_Project_Notebook.ipynb
#  create mode 100644 PhoebePark_env/bin/Activate.ps1
#  create mode 100644 PhoebePark_env/bin/__pycache__/jp.cpython-312.pyc
#  create mode 100644 PhoebePark_env/bin/activate
#  create mode 100644 PhoebePark_env/bin/activate.csh
#  create mode 100644 PhoebePark_env/bin/activate.fish
#  create mode 100755 PhoebePark_env/bin/automat-visualize
#  create mode 100755 PhoebePark_env/bin/cftp
#  create mode 100755 PhoebePark_env/bin/ckeygen
#  create mode 100755 PhoebePark_env/bin/conch
#  create mode 100755 PhoebePark_env/bin/debugpy
#  create mode 100755 PhoebePark_env/bin/debugpy-adapter
#  create mode 100755 PhoebePark_env/bin/f2py
#  create mode 100755 PhoebePark_env/bin/fonttools
#  create mode 100755 PhoebePark_env/bin/incremental
#  create mode 100755 PhoebePark_env/bin/ipython
#  create mode 100755 PhoebePark_env/bin/ipython3
#  create mode 100755 PhoebePark_env/bin/jp.py
#  create mode 100755 PhoebePark_env/bin/jupyter
#  create mode 100755 PhoebePark_env/bin/jupyter-kernel
#  create mode 100755 PhoebePark_env/bin/jupyter-kernelspec
#  create mode 100755 PhoebePark_env/bin/jupyter-migrate
#  create mode 100755 PhoebePark_env/bin/jupyter-run
#  create mode 100755 PhoebePark_env/bin/jupyter-troubleshoot
#  create mode 100755 PhoebePark_env/bin/mailmail
#  create mode 100755 PhoebePark_env/bin/normalizer
#  create mode 100755 PhoebePark_env/bin/numpy-config
#  create mode 100755 PhoebePark_env/bin/pip
#  create mode 100755 PhoebePark_env/bin/pip3
#  create mode 100755 PhoebePark_env/bin/pip3.12
#  create mode 100755 PhoebePark_env/bin/pyftmerge
#  create mode 100755 PhoebePark_env/bin/pyftsubset
#  create mode 100755 PhoebePark_env/bin/pygmentize
#  create mode 100755 PhoebePark_env/bin/pyhtmlizer
#  create mode 120000 PhoebePark_env/bin/python
#  create mode 120000 PhoebePark_env/bin/python3
#  create mode 120000 PhoebePark_env/bin/python3.12
#  create mode 100755 PhoebePark_env/bin/scrapy
#  create mode 100755 PhoebePark_env/bin/scrapyd
#  create mode 100755 PhoebePark_env/bin/scrapyd-client
#  create mode 100755 PhoebePark_env/bin/scrapyd-deploy
#  create mode 100755 PhoebePark_env/bin/tkconch
#  create mode 100755 PhoebePark_env/bin/tldextract
#  create mode 100755 PhoebePark_env/bin/trial
#  create mode 100755 PhoebePark_env/bin/ttx
#  create mode 100755 PhoebePark_env/bin/twist
#  create mode 100755 PhoebePark_env/bin/twistd
#  create mode 100755 PhoebePark_env/bin/update-tld-names
#  create mode 100644 PhoebePark_env/include/site/python3.12/greenlet/greenlet.h
#  create mode 100755 PhoebePark_env/lib/python3.12/site-packages/81d243bd2c585b0f4821__mypyc.cpython-312-x86_64-linux-gnu.so
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/__main__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/__pycache__/__main__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/__pycache__/display.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/__pycache__/paths.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/alias.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/application.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/async_helpers.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/autocall.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/builtin_trap.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/compilerop.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/completer.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/completerlib.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/crashhandler.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/debugger.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/debugger_backport.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/display.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/display_functions.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/display_trap.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/displayhook.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/displaypub.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/doctb.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/error.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/events.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/extensions.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/formatters.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/getipython.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/guarded_eval.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/history.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/historyapp.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/hooks.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/inputtransformer2.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/interactiveshell.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/kitty.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/latex_symbols.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/logger.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/macro.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/magic.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/magic_arguments.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/oinspect.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/page.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/payload.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/payloadpage.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/prefilter.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/profileapp.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/profiledir.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/pylabtools.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/release.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/shellapp.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/splitinput.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/tbtools.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/tips.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/ultratb.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/__pycache__/usage.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/alias.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/application.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/async_helpers.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/autocall.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/builtin_trap.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/compilerop.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/completer.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/completerlib.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/crashhandler.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/debugger.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/debugger_backport.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/display.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/display_functions.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/display_trap.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/displayhook.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/displaypub.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/doctb.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/error.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/events.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/extensions.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/formatters.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/getipython.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/guarded_eval.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/history.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/historyapp.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/hooks.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/inputtransformer2.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/kitty.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/latex_symbols.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/logger.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/macro.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magic.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magic_arguments.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/ast_mod.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/auto.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/basic.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/code.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/config.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/display.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/execution.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/extension.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/history.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/logging.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/namespace.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/osm.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/packaging.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/pylab.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/__pycache__/script.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/ast_mod.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/auto.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/basic.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/code.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/config.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/display.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/execution.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/extension.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/history.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/logging.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/namespace.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/osm.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/packaging.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/pylab.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/magics/script.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/oinspect.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/page.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/payload.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/payloadpage.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/prefilter.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/profile/README_STARTUP
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/profileapp.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/profiledir.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/pylabtools.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/release.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/shellapp.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/splitinput.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/tbtools.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/tips.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/ultratb.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/core/usage.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/display.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/__pycache__/autoreload.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/__pycache__/storemagic.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/autoreload.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/deduperreload/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/deduperreload/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/deduperreload/__pycache__/deduperreload.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/deduperreload/__pycache__/deduperreload_patching.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/deduperreload/deduperreload.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/deduperreload/deduperreload_patching.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/extensions/storemagic.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/__pycache__/pickleshare.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/__pycache__/qt_for_kernel.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/__pycache__/qt_loaders.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/pickleshare.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/qt_for_kernel.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/external/qt_loaders.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/backgroundjobs.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/clipboard.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/deepreload.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/demo.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/display.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/editorhooks.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/guisupport.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/latextools.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/lexers.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/__pycache__/pretty.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/backgroundjobs.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/clipboard.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/deepreload.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/demo.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/display.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/editorhooks.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/guisupport.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/latextools.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/lexers.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/lib/pretty.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/paths.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/py.typed
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/__pycache__/custom_doctests.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/__pycache__/ipython_console_highlighting.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/__pycache__/ipython_directive.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/custom_doctests.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/ipython_console_highlighting.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/sphinxext/ipython_directive.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/debugger.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/embed.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/interactiveshell.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/ipapp.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/magics.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/prompts.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/__pycache__/ptutils.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/debugger.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/embed.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/interactiveshell.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/ipapp.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/magics.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/prompts.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/asyncio.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/glut.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/gtk.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/gtk3.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/gtk4.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/osx.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/pyglet.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/qt.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/tk.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__/wx.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/asyncio.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/glut.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/gtk.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/gtk3.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/gtk4.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/osx.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/pyglet.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/qt.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/tk.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/wx.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/ptutils.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/__pycache__/auto_match.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/__pycache__/auto_suggest.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/__pycache__/filters.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/auto_match.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/auto_suggest.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/terminal/shortcuts/filters.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__pycache__/decorators.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__pycache__/globalipapp.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__pycache__/ipunittest.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__pycache__/skipdoctest.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/__pycache__/tools.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/decorators.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/globalipapp.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/ipunittest.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/dtexample.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/ipdoctest.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/pytest_ipdoctest.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/setup.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/simple.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/simplevars.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/test_ipdoctest.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/__pycache__/test_refs.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/dtexample.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/ipdoctest.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/pytest_ipdoctest.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/setup.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/simple.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/simplevars.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/test_combo.txt
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/test_example.txt
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/test_exampleip.txt
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/test_ipdoctest.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/plugin/test_refs.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/skipdoctest.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/testing/tools.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/PyColorize.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/PyColorize.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_process_cli.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_process_common.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_process_emscripten.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_process_posix.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_process_win32.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_process_win32_controller.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/_sysinfo.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/capture.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/coloransi.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/contexts.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/data.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/decorators.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/dir2.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/docs.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/encoding.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/eventful.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/frame.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/generics.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/importstring.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/io.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/ipstruct.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/jsonutil.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/log.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/module_paths.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/openpy.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/path.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/process.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/py3compat.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/sentinel.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/strdispatch.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/sysinfo.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/syspathcontext.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/tempdir.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/terminal.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/text.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/timing.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/tokenutil.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/__pycache__/wildcard.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_process_cli.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_process_common.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_process_emscripten.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_process_posix.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_process_win32.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_process_win32_controller.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/_sysinfo.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/capture.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/coloransi.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/contexts.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/data.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/decorators.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/dir2.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/docs.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/encoding.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/eventful.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/frame.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/generics.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/importstring.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/io.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/ipstruct.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/jsonutil.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/log.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/module_paths.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/openpy.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/path.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/process.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/py3compat.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/sentinel.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/strdispatch.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/sysinfo.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/syspathcontext.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/tempdir.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/terminal.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/text.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/timing.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/tokenutil.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/IPython/utils/wildcard.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/SSL.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/SSL.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/_util.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/crypto.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/debug.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/rand.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/__pycache__/version.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/_util.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/crypto.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/debug.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/py.typed
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/rand.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/OpenSSL/version.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/AvifImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/BdfFontFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/BlpImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/BmpImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/BufrStubImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ContainerIO.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/CurImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/DcxImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/DdsImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/EpsImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ExifTags.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/FitsImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/FliImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/FontFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/FpxImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/FtexImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/GbrImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/GdImageFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/GifImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/GimpGradientFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/GimpPaletteFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/GribStubImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/Hdf5StubImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/IcnsImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/IcoImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/Image.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageChops.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageCms.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageColor.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageDraw.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageDraw2.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageEnhance.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageFilter.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageFont.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageGrab.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageMath.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageMode.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageMorph.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageOps.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImagePalette.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImagePath.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageQt.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageSequence.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageShow.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageStat.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageText.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageTk.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageTransform.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImageWin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/ImtImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/IptcImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/Jpeg2KImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/JpegImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/JpegPresets.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/McIdasImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/MicImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/MpegImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/MpoImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/MspImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PSDraw.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PaletteFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PalmImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PcdImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PcfFontFile.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PcxImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PdfImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PdfParser.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PixarImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PngImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PpmImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/PsdImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/QoiImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/SgiImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/SpiderImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/SunImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/TarIO.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/TgaImagePlugin.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/PIL/TiffImagePlugin.py
# ...
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/__pycache__/version.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/attrsettr.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/context.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/frame.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/poll.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/socket.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/stopwatch.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/tracker.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/sugar/version.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/tests/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/tests/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/garbage.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/interop.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/jsonapi.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/monitor.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/strtypes.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/win32.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/__pycache__/z85.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/garbage.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/getpid_compat.h
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/interop.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/ipcmaxlen.h
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/jsonapi.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/monitor.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/mutex.h
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/pyversion_compat.h
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/strtypes.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/win32.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/z85.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zmq/utils/zmq_compat.h
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/_compat.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/_flatten.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/adapter.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/advice.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/declarations.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/document.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/exceptions.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/interface.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/interfaces.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/registry.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/ro.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/__pycache__/verify.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/_compat.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/_flatten.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/_zope_interface_coptimizations.c
#  create mode 100755 PhoebePark_env/lib/python3.12/site-packages/zope/interface/_zope_interface_coptimizations.cpython-312-x86_64-linux-gnu.so
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/adapter.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/advice.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/builtins.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/collections.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/idatetime.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/interfaces.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/io.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/mapping.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/numbers.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/__pycache__/sequence.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/builtins.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/collections.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/idatetime.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/interfaces.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/io.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/mapping.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/numbers.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/sequence.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/basemapping.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/test_builtins.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/test_collections.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/test_idatetime.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/test_import_interfaces.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/test_io.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/__pycache__/test_numbers.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/basemapping.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/test_builtins.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/test_collections.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/test_idatetime.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/test_import_interfaces.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/test_io.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/common/tests/test_numbers.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/declarations.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/document.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/exceptions.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/interface.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/interfaces.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/registry.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/ro.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__init__.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/__init__.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/advisory_testing.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/dummy.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/idummy.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/m1.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/odd.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_adapter.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_advice.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_compile_flags.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_declarations.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_document.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_element.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_exceptions.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_interface.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_interfaces.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_odd_declarations.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_registry.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_ro.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_sorting.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/__pycache__/test_verify.cpython-312.pyc
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/advisory_testing.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/dummy.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/idummy.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/m1.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/odd.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_adapter.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_advice.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_compile_flags.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_declarations.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_document.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_element.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_exceptions.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_interface.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_interfaces.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_odd_declarations.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_registry.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_ro.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_sorting.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/tests/test_verify.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope/interface/verify.py
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope_interface-8.4.dist-info/INSTALLER
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope_interface-8.4.dist-info/METADATA
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope_interface-8.4.dist-info/RECORD
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope_interface-8.4.dist-info/WHEEL
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope_interface-8.4.dist-info/licenses/LICENSE.txt
#  create mode 100644 PhoebePark_env/lib/python3.12/site-packages/zope_interface-8.4.dist-info/top_level.txt
#  create mode 120000 PhoebePark_env/lib64
#  create mode 100644 PhoebePark_env/pyvenv.cfg
#  create mode 100644 PhoebePark_env/share/jupyter/kernels/python3/kernel.json
#  create mode 100644 PhoebePark_env/share/jupyter/kernels/python3/logo-32x32.png
#  create mode 100644 PhoebePark_env/share/jupyter/kernels/python3/logo-64x64.png
#  create mode 100644 PhoebePark_env/share/jupyter/kernels/python3/logo-svg.svg
#  create mode 100644 PhoebePark_env/share/man/man1/ipython.1
#  create mode 100644 PhoebePark_env/share/man/man1/ttx.1
#  create mode 100644 scatterplot.png
# Enumerating objects: 24794, done.
# Counting objects: 100% (24794/24794), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (24406/24406), done.
# Writing objects: 100% (24793/24793), 182.72 MiB | 3.42 MiB/s, done.
# Total 24793 (delta 1586), reused 10 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (1586/1586), done.
# To https://github.com/ph02b2/ds1001_final
#    dc46059..05854c7  main -> main
